# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/thieu1995/csv-files/blob/main/data/pandas/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv")

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
gb = drinks.groupby('continent').agg({'beer_servings': 'mean'})

# %%
gb.sort_values('beer_servings', ascending = False)
# Out:
#                beer_servings
# continent
# Europe            193.777778
# South America     175.083333
# North America     145.434783
# Oceania            89.687500
# Africa             61.471698
# Asia               37.045455

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
gb = drinks.groupby('continent').agg({'wine_servings': 'describe'})

# %%
gb
# Out:
#               wine_servings                                                   \
#                       count        mean        std  min   25%    50%     75%
# continent
# Africa                 53.0   16.264151  38.846419  0.0   1.0    2.0   13.00
# Asia                   44.0    9.068182  21.667034  0.0   0.0    1.0    8.00
# Europe                 45.0  142.222222  97.421738  0.0  59.0  128.0  195.00
# North America          23.0   24.521739  28.266378  1.0   5.0   11.0   34.00
# Oceania                16.0   35.625000  64.555790  0.0   1.0    8.5   23.25
# South America          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50
#
#
#                  max
# continent
# Africa         233.0
# Asia           123.0
# Europe         370.0
# North America  100.0
# Oceania        212.0
# South America  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
gb = drinks.groupby('continent').mean()

# %%
gb
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
gb = drinks.groupby('continent').median()

# %%
gb
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa                  32.0              3.0            2.0
# Asia                    17.5             16.0            1.0
# Europe                 219.0            122.0          128.0
# North America          143.0            137.0           11.0
# Oceania                 52.5             37.0            8.5
# South America          162.5            108.5           12.0
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                 2.30
# Asia                                   1.20
# Europe                                10.00
# North America                          6.30
# Oceania                                1.75
# South America                          6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
#                      mean  min  max
# continent
# Africa          16.339623    0  152
# Asia            60.840909    0  326
# Europe         132.555556    0  373
# North America  165.739130   68  438
# Oceania         58.437500    0  254
# South America  114.750000   25  302
